# %% [markdown]
# # TarDAL online tutorial | CVPR 2022
#
# This is the **official** TarDAL notebook, and is freely available for everyone.
# For more information please visit [GitHub Repository](https://github.com/JinyuanLiu-CV/TarDAL).
# Thank you!

# %% [markdown]
# ## Setup Environment
#
# Install requirements for TarDAL.

# %%
# !nvidia-smi  # check GPU environment
# !git clone https://github.com/JinyuanLiu-CV/TarDAL.git  # clone repository from GitHub

# use python 3.10
# !wget https://github.com/korakot/kora/releases/download/v0.10/py310.sh
# !bash ./py310.sh -b -f -p /usr/local
# !python -m ipykernel install --name "py310" --user

# %cd TarDAL
# %pip install -r requirements.txt  # install tardal requirements
# %pip install -r module/detect/requirements.txt # install yolov5 requirements

# %% [markdown]
# ## Fuse or Eval
#
# ### Load Image (List)
#
# infrared image(s):
# ![infrared](assets/sample/s1/ir/M3FD_00471.png)
#
# visible image(s):
# ![visible](assets/sample/s1/vi/M3FD_00471.png)
#
# ### Init TarDAL Pipeline

# %%
from scripts import InferF
from config import from_dict
import yaml
from pathlib import Path
from IPython import display

# init config
config = yaml.safe_load(Path('config/official/colab.yaml').open('r'))
config = from_dict(config)  # convert dict to object

# init infer pipeline
infer_p = InferF(config, save_dir='runs/sample/s1')

# generate fusion sample
infer_p.run()

# display sample
display.Image('runs/sample/s1/M3FD_00471.png')
# Out:
# 2024-10-13 19:01:12,581 | infer_f.py[line:21] | INFO | TarDAL-v1 Inference Script
# 2024-10-13 19:01:12,582 | infer_f.py[line:38] | INFO | create save folder runs/sample/s1
# 2024-10-13 19:01:12,582 | roadscene.py[line:28] | INFO | load 3 images from s1
# 2024-10-13 19:01:12,583 | checker.py[line:21] | INFO | find all images on list
# 2024-10-13 19:01:12,583 | checker.py[line:73] | INFO | find suitable size for prediction
# finding suitable size: 100%|██████████| 3/3 [00:00<00:00, 120.32it/s]
# 2024-10-13 19:01:12,613 | checker.py[line:80] | INFO | max size in dataset: H:768 x W:1024
# 2024-10-13 19:01:12,629 | fuse.py[line:33] | INFO | deploy tardal-fuse on device cuda
# 2024-10-13 19:01:12,634 | fuse.py[line:40] | INFO | init generator with (dim: 32 depth: 3)
# 2024-10-13 19:01:12,634 | fuse.py[line:58] | INFO | download pretrained parameters from https://github.com/JinyuanLiu-CV/TarDAL/releases/download/v1.0.0/tardal-ct.pth
# Downloading: "https://github.com/JinyuanLiu-CV/TarDAL/releases/download/v1.0.0/tardal-ct.pth" to /home/legion/Works/Fusion/TarDAL/weights/v1/tardal-ct.pth
# 100%|██████████| 1.15M/1.15M [00:32<00:00, 36.6kB/s]
# 2024-10-13 19:01:47,299 | fuse.py[line:90] | WARNING | no use_eval settings found, using default (true)
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.27s/it]

# %%
from scripts import InferFD
from config import from_dict
import yaml
from pathlib import Path
from IPython import display

# init config
config = yaml.safe_load(Path('config/official/colab.yaml').open('r'))
config = from_dict(config)  # convert dict to object

# init infer pipeline
infer_p = InferFD(config, save_dir='runs/sample/s2')

# generate fusion sample
infer_p.run()

# display sample
display.Image('runs/sample/s2/M3FD_00471.png')
# Out:
# 2024-10-13 21:02:16,338 | infer_fd.py[line:22] | INFO | TarDAL-v1 Inference Script
# 2024-10-13 21:02:16,339 | infer_fd.py[line:45] | INFO | create save folder runs/sample/s2
# 2024-10-13 21:02:16,339 | m3fd.py[line:43] | WARNING | not found scenario.json, using current train & val list.
# 2024-10-13 21:02:16,340 | m3fd.py[line:47] | INFO | load 3 images from s1
# 2024-10-13 21:02:16,340 | checker.py[line:21] | INFO | find all images on list
# 2024-10-13 21:02:16,340 | checker.py[line:73] | INFO | find suitable size for prediction
# finding suitable size: 100%|██████████| 3/3 [00:00<00:00, 178.56it/s]
# 2024-10-13 21:02:16,360 | checker.py[line:80] | INFO | max size in dataset: H:768 x W:1024
# 2024-10-13 21:02:16,375 | fuse.py[line:33] | INFO | deploy tardal-fuse on device cuda
# 2024-10-13 21:02:16,379 | fuse.py[line:40] | INFO | init generator with (dim: 32 depth: 3)
# 2024-10-13 21:02:16,380 | fuse.py[line:58] | INFO | download pretrained parameters from https://github.com/JinyuanLiu-CV/TarDAL/releases/download/v1.0.0/tardal-ct.pth
# 2024-10-13 21:02:16,384 | fuse.py[line:90] | WARNING | no use_eval settings found, using default (true)
# 2024-10-13 21:02:16,453 | detect.py[line:34] | INFO | deploy yolov5s on device cuda
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 12
#       9 config = from_dict(config)  # convert dict to object
#      11 # init infer pipeline
# ---> 12 infer_p = InferFD(config, save_dir='runs/sample/s2')
#      14 # generate fusion sample
#      15 infer_p.run()
#
# File ~/Works/Fusion/TarDAL/scripts/infer_fd.py:60, in InferFD.__init__(self, config, save_dir)
#      58 fuse = Fuse(config, mode='inference')
#      59 self.fuse = fuse
# ---> 60 detect = Detect(config, mode='inference', nc=len(p_dataset.classes), classes=p_dataset.classes, labels=p_dataset.labels)
#      61 self.detect = detect
#
# File ~/Works/Fusion/TarDAL/pipeline/detect.py:41, in Detect.__init__(self, config, mode, nc, classes, labels)
#      39 config_p = Path(__file__).parents[1] / 'module' / 'detect' / 'models' / f'{model_t}.yaml'
#      40 # net = Model(cfg=config_p, ch=config.detect.channels, nc=nc).to(self.device)
# ---> 41 net = YOLO('yolov5s', 'detect').to(self.device)
#      42 logging.info(f'init {model_t} with (nc: {nc})')
#      43 self.net = net
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/models/yolo/model.py:23, in YOLO.__init__(self, model, task, verbose)
#      20     self.__dict__ = new_instance.__dict__
#      21 else:
#      22     # Continue with default YOLO initialization
# ---> 23     super().__init__(model=model, task=task, verbose=verbose)
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/engine/model.py:145, in Model.__init__(self, model, task, verbose)
#     143     self._new(model, task=task, verbose=verbose)
#     144 else:
# --> 145     self._load(model, task=task)
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/engine/model.py:302, in Model._load(self, weights, task)
#     300     self.ckpt_path = self.model.pt_path
#     301 else:
# --> 302     weights = checks.check_file(weights)  # runs in all cases, not redundant with above call
#     303     self.model, self.ckpt = weights, None
#     304     self.task = task or guess_model_task(weights)
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/utils/checks.py:518, in check_file(file, suffix, download, download_dir, hard)
#     516 files = glob.glob(str(ROOT / "**" / file), recursive=True) or glob.glob(str(ROOT.parent / file))  # find file
#     517 if not files and hard:
# --> 518     raise FileNotFoundError(f"'{file}' does not exist")
#     519 elif len(files) > 1 and hard:
#     520     raise FileNotFoundError(f"Multiple files match '{file}', specify exact path: {files}")
#
# FileNotFoundError: 'yolov5s' does not exist
